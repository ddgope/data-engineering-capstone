# %%
import pandas as pd
import geopandas
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("airport/airport_codes.csv")

# %%
df[['ident','type','name','elevation_ft','continent','iso_country','iso_region','municipality','gps_code','iata_code','local_code','coordinates']]
# Out:
#          ident            type                                      name  \
# 0          00A        heliport                         Total Rf Heliport
# 1         00AA   small_airport                      Aero B Ranch Airport
# 2         00AK   small_airport                              Lowell Field
# 3         00AL   small_airport                              Epps Airpark
# 4         00AR          closed        Newport Hospital & Clinic Heliport
# 5         00AS   small_airport                            Fulton Airport
# 6         00AZ   small_airport                            Cordes Airport
# 7         00CA   small_airport                   Goldstone /Gts/ Airport
# 8         00CL   small_airport                       Williams Ag Airport
# 9         00CN        heliport           Kitchen Creek Helibase Heliport
# 10        00CO          closed                                Cass Field
# 11        00FA   small_airport                       Grass Patch Airport
# ...

# %%
# coordinates is having two different values longitude and latitude 
df[['lat','long']]=df["coordinates"].str.split(",", n = 2, expand = True)

# %%
#Drop columns coordinates and assigned to new dataframe
#airDF=df.drop(['coordinates'], axis=1)

# %%
 df[['long','lat']]

# %%
#Convert from string into float data types
df['long'] = df['long'].astype(float)

# %%
#Convert from string into float data types
df['lat'] = df['lat'].astype(float)

# %%
#write the data into CSV format
df.to_csv("airport/airport.csv", sep=',', encoding='utf-8')
